# %%
# !pip install sweetviz

# %% [markdown]
# ## 1. Read the Advance Housing Pridction Dataset

# %%
import pandas as  pd
df=pd.read_csv('train.csv')

# %% [markdown]
# ## 2. Analyze the Penguins Dataset

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
#X= df.drop["Id",'SalePrice']
#y=df['SalePrice']
X=df.iloc[:,1:81]
y=df.iloc[:,-1]

# %%
X
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
# importing sweetviz
import sweetviz as sv
#analyzing the dataset
advert_report = sv.analyze(df)
advert_report
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
# display the report
advert_report.show_html('train.html')
# Out:
# Report train.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## 3. Side-by-Side Comparison of Train vs Test Set

# %% [markdown]
# ## 3.1. Data Split using 90/10 Split Ratio

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.01)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 864           20       FV         72.0     8640   Pave   NaN      Reg
# 389           60       RL         96.0    12474   Pave   NaN      Reg
# 1303          20       RL         73.0     8688   Pave   NaN      Reg
# 888           20       RL         95.0    15865   Pave   NaN      IR1
# 1192          50       RM         60.0     9600   Pave  Grvl      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 162           20       RL         95.0    12182   Pave   NaN      Reg
# 30            70  C (all)         50.0     8500   Pave  Pave      Reg
# 1156          80       RL         85.0     9350   Pave   NaN      Reg
# 762           60       FV         72.0     8640   Pave   NaN      Reg
# 1158          20       RL         92.0    11932   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
X_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 604           20       RL         88.0    12803   Pave   NaN      IR1
# 613           20       RL         70.0     8402   Pave   NaN      Reg
# 283           20       RL         74.0     9612   Pave   NaN      Reg
# 1087          60       FV         85.0    10574   Pave   NaN      Reg
# 1147          70       RL         75.0    12000   Pave   NaN      Reg
# 1373          20       RL          NaN    11400   Pave   NaN      Reg
# 862           20       RL         81.0     9672   Pave   NaN      Reg
# 1051          20       RL        103.0    11175   Pave   NaN      IR1
# 568           50       RL         79.0    12327   Pave   NaN      IR1
# 1345          30       RM         50.0     6000   Pave   NaN      Reg
# 635          190       RH         60.0    10896   Pave  Pave      Reg
# 230           20       RL         73.0     8760   Pave   NaN      Reg
# ...

# %% [markdown]
# ## 3.2. Comparison Report¶

# %%
import sweetviz as sv
compare_report = sv.compare([X_train, 'Train'], [X_test, 'Test'])
compare_report.show_html('Advance_house_pricing_compare.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# C:\Users\apsgo\anaconda3\lib\site-packages\sweetviz\series_analyzer.py:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts_without_nan = pd.Series()
# C:\Users\apsgo\anaconda3\lib\site-packages\sweetviz\series_analyzer.py:16: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   value_counts_without_nan = pd.Series()
# Report Advance_house_pricing_compare.html was generated.
