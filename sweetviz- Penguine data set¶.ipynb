# %% [markdown]
# # Install sweetiz

# %%
# !pip install sweetviz

# %% [markdown]
# # Penguine data set

# %% [markdown]
# ## 1. Read in the Penguins Dataset

# %%
import pandas as pd
penguins_df = pd.read_csv('https://raw.githubusercontent.com/dataprofessor/data/master/penguins_cleaned.csv')

# %%
# Separating X and y
X = penguins_df.drop('species', axis=1)
y = penguins_df['species']

# %% [markdown]
# ## 2. Analyze the Penguins Dataset

# %%
penguins_df
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %%
import sweetviz as sv
analyze_report = sv.analyze(penguins_df)
analyze_report.show_html('analyze.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report analyze.html was generated.

# %% [markdown]
# ![Web%20capture_1-7-2022_135035_.jpeg](attachment:Web%20capture_1-7-2022_135035_.jpeg)

# %%
import IPython
IPython.display.HTML('analyze.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ## 3. Side-by-Side Comparison of Train vs Test Set

# %% [markdown]
# ### 3.1. Data Split using 80/20 Split Ratio

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#         island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 251     Biscoe            43.3           14.0                208         4575
# 320      Dream            52.2           18.8                197         3450
# 262     Biscoe            50.4           15.7                222         5750
# 26       Dream            37.2           18.1                178         3900
# 52      Biscoe            36.5           16.6                181         2850
# ..         ...             ...            ...                ...          ...
# 115  Torgersen            37.7           19.8                198         3500
# 232     Biscoe            47.5           14.0                212         4875
# 314      Dream            49.8           17.3                198         3675
# 173     Biscoe            48.2           14.3                210         4600
# 8    Torgersen            38.6           21.2                191         3800
#
#         sex
# 251  female
# ...

# %%
X_test
# Out:
#         island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 10   Torgersen            36.6           17.8                185         3700
# 275      Dream            46.6           17.8                193         3800
# 217     Biscoe            46.5           14.8                217         5200
# 93       Dream            43.2           18.5                192         4100
# 284      Dream            49.2           18.2                195         4400
# ..         ...             ...            ...                ...          ...
# 102     Biscoe            38.1           17.0                181         3175
# 18      Biscoe            38.2           18.1                185         3950
# 180     Biscoe            48.4           16.3                220         5400
# 105     Biscoe            45.6           20.3                191         4600
# 195     Biscoe            46.6           14.2                210         4850
#
#         sex
# 10   female
# ...

# %% [markdown]
# ### 3.2. Comparison Report

# %%
import sweetviz as sv
compare_report = sv.compare([X_train, 'Train'], [X_test, 'Test'])
compare_report.show_html('compare.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report compare.html was generated.

# %% [markdown]
# ![Web%20capture_1-7-2022_141425_localhost.jpeg](attachment:Web%20capture_1-7-2022_141425_localhost.jpeg)

# %% [markdown]
# ![Web%20capture_1-7-2022_141637_localhost.jpeg](attachment:Web%20capture_1-7-2022_141637_localhost.jpeg)
